# %%
import numpy as np # for linear algebra
import pandas as pd # data preprocessing
import matplotlib.pyplot as plt # data visualization library
import seaborn as sns # data visualization library
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') # ignore warnings 

from sklearn.preprocessing import MinMaxScaler # for normalization
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv('Task_1_Stocks_dataset.csv') # data_importing
df.head(10)
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
# 5   GOOG  2016-06-21 00:00:00+00:00  695.94  702.77  692.0100  698.40
# 6   GOOG  2016-06-22 00:00:00+00:00  697.46  700.86  693.0819  699.06
# 7   GOOG  2016-06-23 00:00:00+00:00  701.87  701.95  687.0000  697.45
# 8   GOOG  2016-06-24 00:00:00+00:00  675.22  689.40  673.4500  675.17
# 9   GOOG  2016-06-27 00:00:00+00:00  668.26  672.30  663.2840  671.00
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
# 5  1465634    695.94   702.77  692.0100   698.40    1465634      0.0
# 6  1184318    697.46   700.86  693.0819   699.06    1184318      0.0
# 7  2171415    701.87   701.95  687.0000   697.45    2171415      0.0
# 8  4449022    675.22   689.40  673.4500   675.17    4449022      0.0
# 9  2641085    668.26   672.30  663.2840   671.00    2641085      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          1.0
# 7          1.0
# 8          1.0
# 9          1.0

# %%
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1258, 14)

# %%
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %%
df = df[['date','open','close']] # Extracting required columns
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) # converting object dtype of date column to datetime dtype
df.set_index('date',drop=True,inplace=True) # Setting date column as index
df.head(10)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26

# %%
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %%
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000

# %%
training_size = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data) 
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %%
model = Sequential()

model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1)) 
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 12s 123ms/step - loss: 0.0090 - mean_absolute_error: 0.0669 - val_loss: 0.0253 - val_mean_absolute_error: 0.1369
# Epoch 2/100
# 28/28 [==============================] - 2s 72ms/step - loss: 7.8642e-04 - mean_absolute_error: 0.0221 - val_loss: 0.0031 - val_mean_absolute_error: 0.0431
# Epoch 3/100
# 28/28 [==============================] - 2s 55ms/step - loss: 4.6916e-04 - mean_absolute_error: 0.0159 - val_loss: 0.0038 - val_mean_absolute_error: 0.0478
# Epoch 4/100
# 28/28 [==============================] - 2s 73ms/step - loss: 4.7776e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0033 - val_mean_absolute_error: 0.0435
# Epoch 5/100
# 28/28 [==============================] - 1s 51ms/step - loss: 4.1627e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0034 - val_mean_absolute_error: 0.0445
# Epoch 6/100
# 28/28 [==============================] - 1s 52ms/step - loss: 4.1045e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0021 - val_mean_absolute_error: 0.0347
# Epoch 7/100
# 28/28 [==============================] - 1s 54ms/step - loss: 3.9941e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0026 - val_mean_absolute_error: 0.0383
# Epoch 8/100
# 28/28 [==============================] - 2s 54ms/step - loss: 4.0238e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0040 - val_mean_absolute_error: 0.0485
# Epoch 9/100
# 28/28 [==============================] - 2s 53ms/step - loss: 3.5922e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0048 - val_mean_absolute_error: 0.0539
# Epoch 10/100
# 28/28 [==============================] - 2s 60ms/step - loss: 3.7113e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0029 - val_mean_absolute_error: 0.0401
# Epoch 11/100
# 28/28 [==============================] - 2s 71ms/step - loss: 3.7597e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0045 - val_mean_absolute_error: 0.0515
# Epoch 12/100
# 28/28 [==============================] - 2s 73ms/step - loss: 4.1569e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0051 - val_mean_absolute_error: 0.0568
# Epoch 13/100
# 28/28 [==============================] - 1s 52ms/step - loss: 3.6039e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0034 - val_mean_absolute_error: 0.0445
# Epoch 14/100
# 28/28 [==============================] - 2s 54ms/step - loss: 3.3066e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0039 - val_mean_absolute_error: 0.0478
# Epoch 15/100
# 28/28 [==============================] - 2s 54ms/step - loss: 3.2635e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0047 - val_mean_absolute_error: 0.0540
# Epoch 16/100
# 28/28 [==============================] - 2s 54ms/step - loss: 3.5393e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0047 - val_mean_absolute_error: 0.0532
# Epoch 17/100
# 28/28 [==============================] - 1s 54ms/step - loss: 3.1742e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0050 - val_mean_absolute_error: 0.0556
# Epoch 18/100
# 28/28 [==============================] - 1s 53ms/step - loss: 3.1594e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0069 - val_mean_absolute_error: 0.0676
# Epoch 19/100
# 28/28 [==============================] - 2s 55ms/step - loss: 3.1761e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0047 - val_mean_absolute_error: 0.0531
# Epoch 20/100
# 28/28 [==============================] - 2s 78ms/step - loss: 3.1858e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0046 - val_mean_absolute_error: 0.0522
# Epoch 21/100
# 28/28 [==============================] - 2s 53ms/step - loss: 2.9821e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0072 - val_mean_absolute_error: 0.0692
# Epoch 22/100
# 28/28 [==============================] - 2s 81ms/step - loss: 3.1175e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0060 - val_mean_absolute_error: 0.0621
# Epoch 23/100
# 28/28 [==============================] - 1s 52ms/step - loss: 2.8908e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0055 - val_mean_absolute_error: 0.0595
# Epoch 24/100
# 28/28 [==============================] - 2s 58ms/step - loss: 3.2328e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0055 - val_mean_absolute_error: 0.0596
# Epoch 25/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.7591e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0050 - val_mean_absolute_error: 0.0566
# Epoch 26/100
# 28/28 [==============================] - 1s 52ms/step - loss: 2.8305e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0034 - val_mean_absolute_error: 0.0445
# Epoch 27/100
# 28/28 [==============================] - 2s 55ms/step - loss: 2.8026e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0039 - val_mean_absolute_error: 0.0476
# Epoch 28/100
# 28/28 [==============================] - 2s 53ms/step - loss: 2.7993e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0042 - val_mean_absolute_error: 0.0492
# Epoch 29/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.6670e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0044 - val_mean_absolute_error: 0.0510
# Epoch 30/100
# 28/28 [==============================] - 2s 77ms/step - loss: 2.5475e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0030 - val_mean_absolute_error: 0.0403
# Epoch 31/100
# 28/28 [==============================] - 2s 77ms/step - loss: 2.7371e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0057 - val_mean_absolute_error: 0.0600
# Epoch 32/100
# 28/28 [==============================] - 1s 53ms/step - loss: 3.0052e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0019 - val_mean_absolute_error: 0.0319
# Epoch 33/100
# 28/28 [==============================] - 1s 50ms/step - loss: 2.9786e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0027 - val_mean_absolute_error: 0.0392
# Epoch 34/100
# 28/28 [==============================] - 1s 52ms/step - loss: 2.7940e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0049 - val_mean_absolute_error: 0.0565
# Epoch 35/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.6770e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0034 - val_mean_absolute_error: 0.0438
# Epoch 36/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.4622e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0032 - val_mean_absolute_error: 0.0422
# Epoch 37/100
# 28/28 [==============================] - 1s 52ms/step - loss: 2.3894e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0033 - val_mean_absolute_error: 0.0433
# Epoch 38/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.2531e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0036 - val_mean_absolute_error: 0.0456
# Epoch 39/100
# 28/28 [==============================] - 2s 55ms/step - loss: 2.8374e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0046 - val_mean_absolute_error: 0.0539
# Epoch 40/100
# 28/28 [==============================] - 2s 78ms/step - loss: 2.3197e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0039 - val_mean_absolute_error: 0.0493
# Epoch 41/100
# 28/28 [==============================] - 2s 79ms/step - loss: 2.3945e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0034 - val_mean_absolute_error: 0.0449
# Epoch 42/100
# 28/28 [==============================] - 2s 76ms/step - loss: 2.1429e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0056 - val_mean_absolute_error: 0.0609
# Epoch 43/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.2100e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0027 - val_mean_absolute_error: 0.0391
# Epoch 44/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.2437e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0047 - val_mean_absolute_error: 0.0557
# Epoch 45/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.1345e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0023 - val_mean_absolute_error: 0.0352
# Epoch 46/100
# 28/28 [==============================] - 2s 57ms/step - loss: 2.4032e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0023 - val_mean_absolute_error: 0.0359
# Epoch 47/100
# 28/28 [==============================] - 2s 58ms/step - loss: 2.1455e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0024 - val_mean_absolute_error: 0.0363
# Epoch 48/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.1137e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0029 - val_mean_absolute_error: 0.0409
# Epoch 49/100
# 28/28 [==============================] - 2s 55ms/step - loss: 2.0913e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0044 - val_mean_absolute_error: 0.0544
# Epoch 50/100
# 28/28 [==============================] - 2s 55ms/step - loss: 2.0664e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0031 - val_mean_absolute_error: 0.0426
# Epoch 51/100
# 28/28 [==============================] - 2s 64ms/step - loss: 2.1859e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0024 - val_mean_absolute_error: 0.0355
# Epoch 52/100
# 28/28 [==============================] - 2s 79ms/step - loss: 2.1008e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0022 - val_mean_absolute_error: 0.0355
# Epoch 53/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.9525e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0033 - val_mean_absolute_error: 0.0450
# Epoch 54/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.8997e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0019 - val_mean_absolute_error: 0.0320
# Epoch 55/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.9835e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0025 - val_mean_absolute_error: 0.0368
# Epoch 56/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.9035e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0028 - val_mean_absolute_error: 0.0399
# Epoch 57/100
# 28/28 [==============================] - 2s 60ms/step - loss: 1.8947e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0015 - val_mean_absolute_error: 0.0280
# Epoch 58/100
# 28/28 [==============================] - 2s 68ms/step - loss: 1.8800e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0031 - val_mean_absolute_error: 0.0427
# Epoch 59/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.7633e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0025 - val_mean_absolute_error: 0.0383
# Epoch 60/100
# 28/28 [==============================] - 2s 80ms/step - loss: 1.7694e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0017 - val_mean_absolute_error: 0.0297
# Epoch 61/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.7752e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0023 - val_mean_absolute_error: 0.0365
# Epoch 62/100
# 28/28 [==============================] - 1s 52ms/step - loss: 1.7382e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0040 - val_mean_absolute_error: 0.0509
# Epoch 63/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.7091e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0021 - val_mean_absolute_error: 0.0342
# Epoch 64/100
# 28/28 [==============================] - 1s 54ms/step - loss: 1.6182e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0041 - val_mean_absolute_error: 0.0512
# Epoch 65/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.8278e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0027 - val_mean_absolute_error: 0.0405
# Epoch 66/100
# 28/28 [==============================] - 1s 54ms/step - loss: 1.5866e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0021 - val_mean_absolute_error: 0.0343
# Epoch 67/100
# 28/28 [==============================] - 2s 64ms/step - loss: 1.5961e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0010 - val_mean_absolute_error: 0.0229
# Epoch 68/100
# 28/28 [==============================] - 2s 59ms/step - loss: 1.5992e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0029 - val_mean_absolute_error: 0.0430
# Epoch 69/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.7838e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0018 - val_mean_absolute_error: 0.0324
# Epoch 70/100
# 28/28 [==============================] - 1s 52ms/step - loss: 1.5197e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0035 - val_mean_absolute_error: 0.0477
# Epoch 71/100
# 28/28 [==============================] - 1s 52ms/step - loss: 1.5461e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0017 - val_mean_absolute_error: 0.0297
# Epoch 72/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.5571e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0016 - val_mean_absolute_error: 0.0294
# Epoch 73/100
# 28/28 [==============================] - 2s 53ms/step - loss: 1.5624e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0023 - val_mean_absolute_error: 0.0367
# Epoch 74/100
# 28/28 [==============================] - 1s 52ms/step - loss: 1.3646e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0022 - val_mean_absolute_error: 0.0364
# Epoch 75/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.8267e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0011 - val_mean_absolute_error: 0.0236
# Epoch 76/100
# 28/28 [==============================] - 1s 52ms/step - loss: 1.5130e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0021 - val_mean_absolute_error: 0.0359
# Epoch 77/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.3429e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0019 - val_mean_absolute_error: 0.0322
# Epoch 78/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.3563e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0030 - val_mean_absolute_error: 0.0444
# Epoch 79/100
# 28/28 [==============================] - 2s 79ms/step - loss: 1.5559e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0021 - val_mean_absolute_error: 0.0368
# Epoch 80/100
# 28/28 [==============================] - 2s 80ms/step - loss: 1.2412e-04 - mean_absolute_error: 0.0081 - val_loss: 9.7425e-04 - val_mean_absolute_error: 0.0226
# Epoch 81/100
# 28/28 [==============================] - 2s 81ms/step - loss: 1.4799e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0024 - val_mean_absolute_error: 0.0398
# Epoch 82/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.2545e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0016 - val_mean_absolute_error: 0.0299
# Epoch 83/100
# 28/28 [==============================] - 1s 52ms/step - loss: 1.3402e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0012 - val_mean_absolute_error: 0.0253
# Epoch 84/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.2527e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0014 - val_mean_absolute_error: 0.0284
# Epoch 85/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.3096e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0016 - val_mean_absolute_error: 0.0304
# Epoch 86/100
# 28/28 [==============================] - 2s 80ms/step - loss: 1.4324e-04 - mean_absolute_error: 0.0085 - val_loss: 7.7127e-04 - val_mean_absolute_error: 0.0200
# Epoch 87/100
# 28/28 [==============================] - 2s 53ms/step - loss: 1.3625e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0019 - val_mean_absolute_error: 0.0341
# Epoch 88/100
# 28/28 [==============================] - 2s 80ms/step - loss: 1.2173e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0015 - val_mean_absolute_error: 0.0288
# Epoch 89/100
# 28/28 [==============================] - 2s 79ms/step - loss: 1.2973e-04 - mean_absolute_error: 0.0081 - val_loss: 7.1879e-04 - val_mean_absolute_error: 0.0192
# Epoch 90/100
# 28/28 [==============================] - 2s 79ms/step - loss: 1.2858e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0036 - val_mean_absolute_error: 0.0497
# Epoch 91/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.5846e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0023 - val_mean_absolute_error: 0.0380
# Epoch 92/100
# 28/28 [==============================] - 1s 52ms/step - loss: 1.2296e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0017 - val_mean_absolute_error: 0.0318
# Epoch 93/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.1807e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0011 - val_mean_absolute_error: 0.0245
# Epoch 94/100
# 28/28 [==============================] - 1s 49ms/step - loss: 1.3450e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0013 - val_mean_absolute_error: 0.0272
# Epoch 95/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.2051e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0018 - val_mean_absolute_error: 0.0336
# Epoch 96/100
# 28/28 [==============================] - 2s 79ms/step - loss: 1.1017e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0026 - val_mean_absolute_error: 0.0419
# Epoch 97/100
# 28/28 [==============================] - 2s 82ms/step - loss: 1.3899e-04 - mean_absolute_error: 0.0085 - val_loss: 7.1455e-04 - val_mean_absolute_error: 0.0195
# Epoch 98/100
# 28/28 [==============================] - 2s 75ms/step - loss: 1.1428e-04 - mean_absolute_error: 0.0077 - val_loss: 5.2035e-04 - val_mean_absolute_error: 0.0164
# Epoch 99/100
# 28/28 [==============================] - 1s 51ms/step - loss: 1.1496e-04 - mean_absolute_error: 0.0075 - val_loss: 9.1692e-04 - val_mean_absolute_error: 0.0227
# Epoch 100/100
# 28/28 [==============================] - 1s 52ms/step - loss: 1.1020e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0013 - val_mean_absolute_error: 0.0278

# %%
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 2s 23ms/step
# array([[0.3967072 , 0.40024975],
#        [0.39744854, 0.40097472],
#        [0.39473328, 0.3983005 ],
#        [0.39795226, 0.4015236 ],
#        [0.40175873, 0.40531686]], dtype=float32)

# %%
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1406.4634, 1410.0588],
#        [1407.8378, 1411.4025],
#        [1402.8038, 1406.4463],
#        [1408.7716, 1412.4198],
#        [1415.8286, 1419.45  ]], dtype=float32)

# %%
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1406.463379      1410.058838
# 2020-05-28  1396.86  1416.73     1407.837769      1411.402466
# 2020-05-29  1416.94  1428.92     1402.803833      1406.446289
# 2020-06-01  1418.39  1431.82     1408.771606      1412.419800
# 2020-06-02  1430.55  1439.22     1415.828613      1419.449951

# %%
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %%
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 40ms/step

# %%
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()
